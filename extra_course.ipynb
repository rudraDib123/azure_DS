# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
X = df['total_bill']
Y = df['tip']

# %%
plt.scatter(X,Y)
plt.xlabel("total Bill")
plt.ylabel('tips')
# Out:
# Text(0, 0.5, 'tips')

# %%
#BarPlot usefull for categorical data , for eg here we have smoker or non smoker

# %%
sns.countplot(data =df,x = 'smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
df.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
plt.pie(df.day.value_counts(),autopct='%.2f%%',labels=list(df.day.unique()),explode=[0,0,0,0.5])
# Out:
# ([<matplotlib.patches.Wedge at 0x25bbba13760>,
# ...
#  [Text(0.47909423581850485, 0.990186201280084, 'Sun'),
#   Text(-1.0967192869113325, -0.08489290734035711, 'Sat'),
#   Text(0.3074340394718734, -1.0561649072820052, 'Thur'),
#   Text(1.5523622803620798, -0.3875194840379559, 'Fri')],
#  [Text(0.26132412862827537, 0.5401015643345912, '35.66%'),
#   Text(-0.598210520133454, -0.04630522218564932, '31.15%'),
#   Text(0.16769129425738546, -0.5760899494265482, '25.41%'),
#   Text(1.06724906774893, -0.2664196452760947, '7.79%')])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.hist(df.tip,bins=5)
# Out:
# (array([120.,  93.,  24.,   5.,   2.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.boxplot(x = 'smoker',y = 'total_bill',data =df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
plt.boxplot([df[df['smoker'] == 'Yes']['total_bill'], df[df['smoker'] == 'No']['total_bill']], labels=list(df.smoker.unique()),patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25bbdd35bb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25bbdbc70a0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x25bbdd35820>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x25bbdbc75e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x25bbdbc7880>,
# ...
#  'means': []}

# %%
sns.stripplot(data=df,x='time',y='tip',jitter=True)
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.countplot(data=df,x = 'time')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
# bivariate analysis with count plot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = 'day',hue='sex',data= df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
#univariate analysis with count plot
sns.countplot(x='sex',data= df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = 'day',data= df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
#Bi variate analysis with hist plot

sns.histplot(data=df,x='day',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
g = sns.FacetGrid(df, col="day", hue="sex", height=4, aspect=0.7)
g.map(plt.hist, "total_bill", alpha=0.7, bins=15)
g.add_legend()
plt.show()

# %%
#week 2

# %%
#Referral Data

# %%
df = pd.read_csv("Referral_Join_Prediction.csv")

# %%
df.head()
# Out:
#    referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0            1            28                    5.0                   Delhi
# 1            2            26                    3.0                    Pune
# 2            3            23                    2.0                  Mumbai
# 3            4            29                    6.0               Bangalore
# 4            5            26                    3.0                  Mumbai
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                      106                  89.0                   72
# 1                       65                  63.0                   77
# 2                       45                  92.0                   85
# 3                      126                  60.0                   95
# 4                       65                  92.0                   70
#
#    referral_graduation_marks  referral_post_grad_marks referral_gender  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   referral_id                          499 non-null    int64
#  1   referral_age                         499 non-null    int64
#  2   referral_exp_in_years                499 non-null    float64
#  3   referral_preferred_city              499 non-null    object
#  4   referral_current_salary              499 non-null    int64
#  5   referral_10_th_marks                 498 non-null    float64
#  6   referral_12th_marks                  499 non-null    int64
#  7   referral_graduation_marks            498 non-null    float64
#  8   referral_post_grad_marks             498 non-null    float64
#  9   referral_gender                      499 non-null    object
#  10  referral_expected_sal                497 non-null    float64
# ...

# %%
df['referral_10_th_marks']
# Out:
# 0      89.0
# 1      63.0
# 2      92.0
# 3      60.0
# 4      92.0
#        ...
# 494    81.0
# 495    74.0
# 496    94.0
# 497    64.0
# 498    67.0
# Name: referral_10_th_marks, Length: 499, dtype: float64

# %%
sns.boxplot(df['referral_10_th_marks'])
# Out:
# <Axes: >

# %%
df[df['referral_10_th_marks']<10]
# Out:
#     referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 89           90            27                    4.0               Bangalore
#
#     referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 89                       85                  -1.0                   81
#
#     referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 89                       93.0                      86.0          Female
#
#     referral_expected_sal referral_aptitude_numerical_score  \
# 89                  103.0                             31.74
#
#     referral_aptitude_verbal_score referral_aptitude_reasoning_score  \
# 89                            6.52                             30.43
#
#     referral_Management_Interview_score  referral_HR_Interview_score  \
# 89                                 10.0                            3
#
#     Salary offered Emp_Salary_Grade Joined
# 89             101              EL0    Yes

# %%
df[df['referral_10_th_marks']<30]
# Out:
#     referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 89           90            27                    4.0               Bangalore
#
#     referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 89                       85                  -1.0                   81
#
#     referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 89                       93.0                      86.0          Female
#
#     referral_expected_sal referral_aptitude_numerical_score  \
# 89                  103.0                             31.74
#
#     referral_aptitude_verbal_score referral_aptitude_reasoning_score  \
# 89                            6.52                             30.43
#
#     referral_Management_Interview_score  referral_HR_Interview_score  \
# 89                                 10.0                            3
#
#     Salary offered Emp_Salary_Grade Joined
# 89             101              EL0    Yes

# %%
marks_12th  = df[df['referral_10_th_marks']<30].referral_12th_marks.values[0]

# %%
df['referral_10_th_marks'] = df.referral_10_th_marks.replace(to_replace=-1,value=marks_12th).astype('float')

# %%
df.iloc[89]
# Out:
# referral_id                                   90
# referral_age                                  27
# referral_exp_in_years                        4.0
# referral_preferred_city                Bangalore
# referral_current_salary                       85
# referral_10_th_marks                        81.0
# referral_12th_marks                           81
# referral_graduation_marks                   93.0
# referral_post_grad_marks                    86.0
# referral_gender                           Female
# referral_expected_sal                      103.0
# referral_aptitude_numerical_score          31.74
# referral_aptitude_verbal_score              6.52
# referral_aptitude_reasoning_score          30.43
# referral_Management_Interview_score         10.0
# referral_HR_Interview_score                    3
# Salary offered                               101
# Emp_Salary_Grade                             EL0
# Joined                                       Yes
# Name: 89, dtype: object

# %%
df.head()
# Out:
#    referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0            1            28                    5.0                   Delhi
# 1            2            26                    3.0                    Pune
# 2            3            23                    2.0                  Mumbai
# 3            4            29                    6.0               Bangalore
# 4            5            26                    3.0                  Mumbai
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                      106                  89.0                   72
# 1                       65                  63.0                   77
# 2                       45                  92.0                   85
# 3                      126                  60.0                   95
# 4                       65                  92.0                   70
#
#    referral_graduation_marks  referral_post_grad_marks referral_gender  \
# ...

# %%
df.describe().T
# Out:
#                                      count        mean         std    min  \
# referral_id                          499.0  250.000000  144.193157   1.00
# referral_age                         499.0   27.020040    2.811979  20.00
# referral_exp_in_years                499.0    4.053307    2.609814   1.00
# referral_current_salary              499.0   86.472946   52.566584  25.00
# referral_10_th_marks                 498.0   77.459839   10.559375  60.00
# referral_12th_marks                  499.0   77.478958   10.932113  12.00
# referral_graduation_marks            498.0   77.096386   10.812223  -1.00
# referral_post_grad_marks             498.0   78.269076   10.478487  60.00
# referral_expected_sal                497.0  108.692153   58.722281  40.00
# referral_aptitude_verbal_score       489.0   21.840491   12.338425   0.43
# referral_Management_Interview_score  498.0    5.732932    2.922706   1.00
# referral_HR_Interview_score          499.0    5.651303    5.500516   1.00
# ...

# %%
df['referral_10_th_marks'].max()
# Out:
# 103.0

# %%
df[df['referral_10_th_marks']>100]
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 400          401            26                    3.0                  Mumbai
#
#      referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 400                       65                 103.0                   69
#
#      referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 400                       70.0                      79.0          Female
#
#      referral_expected_sal referral_aptitude_numerical_score  \
# 400                   83.0                             40.87
#
#      referral_aptitude_verbal_score referral_aptitude_reasoning_score  \
# 400                           33.48                             24.35
#
#      referral_Management_Interview_score  referral_HR_Interview_score  \
# 400                                  4.0                           10
#
#      Salary offered Emp_Salary_Grade Joined
# 400              80              ML0     No

# %%
df.head(50)
# Out:
#     referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0             1            28                    5.0                   Delhi
# 1             2            26                    3.0                    Pune
# 2             3            23                    2.0                  Mumbai
# 3             4            29                    6.0               Bangalore
# 4             5            26                    3.0                  Mumbai
# 5             6            29                    6.0               Bangalore
# 6             7            30                    7.0               Bangalore
# 7             8            29                    6.0                  Mumbai
# 8             9            24                    3.0                  Mumbai
# 9            10            29                    5.0               Bangalore
# 10           11            22                    1.0                    Pune
# ...

# %%
sns.histplot(data=df,x = 'referral_10_th_marks')
# Out:
# <Axes: xlabel='referral_10_th_marks', ylabel='Count'>

# %%
sns.boxplot(data=df,x = 'referral_10_th_marks')
# Out:
# <Axes: xlabel='referral_10_th_marks'>

# %%
#df['referral_10_th_marks'] = np.where(df['referral_10_th_marks']>100,df.referral_10_th_marks.median(),df.referral_10_th_marks)

# %%
#df.iloc[400]

# %%
sns.boxplot(data=df,x = 'referral_10_th_marks')
# Out:
# <Axes: xlabel='referral_10_th_marks'>

# %%
df.describe().T
# Out:
#                                      count        mean         std    min  \
# referral_id                          499.0  250.000000  144.193157   1.00
# referral_age                         499.0   27.020040    2.811979  20.00
# referral_exp_in_years                499.0    4.053307    2.609814   1.00
# referral_current_salary              499.0   86.472946   52.566584  25.00
# referral_10_th_marks                 498.0   77.459839   10.559375  60.00
# referral_12th_marks                  499.0   77.478958   10.932113  12.00
# referral_graduation_marks            498.0   77.096386   10.812223  -1.00
# referral_post_grad_marks             498.0   78.269076   10.478487  60.00
# referral_expected_sal                497.0  108.692153   58.722281  40.00
# referral_aptitude_verbal_score       489.0   21.840491   12.338425   0.43
# referral_Management_Interview_score  498.0    5.732932    2.922706   1.00
# referral_HR_Interview_score          499.0    5.651303    5.500516   1.00
# ...

# %%
df['referral_10_th_marks'] = np.where(df['referral_10_th_marks']>100,df.referral_10_th_marks.quantile(0.75),df.referral_10_th_marks)

# %%
df.iloc[400]
# Out:
# referral_id                               401
# referral_age                               26
# referral_exp_in_years                     3.0
# referral_preferred_city                Mumbai
# referral_current_salary                    65
# referral_10_th_marks                     87.0
# referral_12th_marks                        69
# referral_graduation_marks                70.0
# referral_post_grad_marks                 79.0
# referral_gender                        Female
# referral_expected_sal                    83.0
# referral_aptitude_numerical_score       40.87
# referral_aptitude_verbal_score          33.48
# referral_aptitude_reasoning_score       24.35
# referral_Management_Interview_score       4.0
# referral_HR_Interview_score                10
# Salary offered                             80
# Emp_Salary_Grade                          ML0
# Joined                                     No
# Name: 400, dtype: object

# %%
df.dropna()
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0              1            28                    5.0                   Delhi
# 1              2            26                    3.0                    Pune
# 2              3            23                    2.0                  Mumbai
# 3              4            29                    6.0               Bangalore
# 4              5            26                    3.0                  Mumbai
# ..           ...           ...                    ...                     ...
# 494          495            21                    1.0                    Pune
# 495          496            21                    1.0                  Mumbai
# 496          497            29                    7.0                  Mumbai
# 497          498            30                    7.0                  Mumbai
# 498          499            30                    8.0               Bangalore
#
# ...
